# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
plt.style.use('seaborn-whitegrid')

# %%
dfnym=pd.read_csv('tablanym.csv')
dfny=pd.read_csv('tablany.csv')
dfnym.rename(columns={'Win%[11]':'Winsnym'},inplace=True)
dfny.rename(columns={'Win%[11]':'Winsny'},inplace=True)
dfny.sort(['Yankees season'])
dfnym.sort(['Mets season'])
nym=dfnym[dfnym['Mets season']>=1970]
len(nym)
ny=dfny[dfny['Yankees season']>=1970]
len(ny)
ny=ny.sort(['Yankees season'])
ny
nym=nym.sort(['Mets season'])
nym
nym=nym.set_index([nym['Mets season']])
nym['Winsnym']
ny=ny.set_index([ny['Yankees season']])
ny['Winsny']
# Out:
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:5: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:6: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:11: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:13: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# Yankees season
# 1970    0.574
# 1971    0.506
# 1972    0.510
# 1973    0.494
# 1974    0.549
# 1975    0.519
# 1976    0.610
# 1977    0.617
# 1978    0.613
# 1979    0.556
# 1980    0.636
# 1981    0.607
# 1982    0.488
# 1983    0.562
# 1984    0.537
# 1985    0.602
# 1986    0.556
# 1987    0.549
# 1988    0.528
# 1989    0.460
# 1990    0.414
# 1991    0.438
# 1992    0.469
# 1993    0.543
# 1994    0.619
# 1995    0.549
# ...

# %%
plt.plot(ny['Winsny'])
plt.plot(nym['Winsnym'],color='red')
plt.xticks(range(1970,2016,5),rotation='45')
plt.legend(['New York Yankees','New York Mets'],loc='lower center')
plt.gca().axis([1970, 2016, 0, 0.9])
plt.ylabel('Winning Percentage')
plt.xlabel('Years')
plt.title('Comparasion between the New York Mets and New York Yankees\n winning record\n 1970-2016 ')
# Out:
# <img src="data:image/png;base64,..." width="697">
